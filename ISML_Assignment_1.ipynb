# %%
import numpy as np
import pandas as pd
import math as math
import cvxpy as cp

print("start")
# Out:
# start

# %%
train = pd.read_csv('./train.csv').head(4000)
test = pd.read_csv('./test.csv')
print(train)
print(test)
# Out:
#       0.00  -0.36  -0.91  -0.99  -0.57  -1.38  -1.54  -1.64  1.29  0.65  ...  \
# 0      1.0  -1.40  -1.90   0.09   0.29  -0.30  -1.30   1.13 -2.38 -1.16  ...
# 1      1.0  -0.43   1.45  -0.68  -1.58   0.32  -0.14   0.23 -1.01 -0.39  ...
# 2      1.0  -0.76   0.30  -0.57  -0.33  -1.50   1.84   1.37  0.23  0.66  ...
# 3      0.0  -0.76   1.36   0.00  -1.44  -1.27  -0.76  -1.42 -0.58  0.11  ...
# 4      1.0  -0.70   0.83  -1.57   1.15   0.79  -0.02  -0.24 -2.58  0.73  ...
# ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...  ...
# 3995   1.0  -0.42  -2.15   1.14  -1.00   1.01   0.56  -2.92 -0.77  1.33  ...
# 3996   1.0  -0.57   0.14  -0.62  -0.63  -0.15   1.74  -0.85 -1.77  0.27  ...
# 3997   1.0   0.40   0.16  -0.49  -0.15  -0.34   0.25   0.18 -0.97 -0.49  ...
# 3998   1.0   0.86  -0.23  -2.01   0.14   0.88  -0.37  -0.01  0.31  0.19  ...
# 3999   0.0  -0.26   0.66   0.31  -0.79   0.05  -0.66  -2.85 -0.13 -1.09  ...
#
# ...
